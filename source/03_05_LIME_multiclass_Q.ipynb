# %%
from sklearn.datasets import load_wine
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import lime
import lime.lime_tabular

# Caricamento del dataset Wine
wine = load_wine()
X = wine.data
y = wine.target

# Dividere il dataset in set di addestramento e test

# Addestramento del modello Random Forest

# Valutazione del modello

# Utilizzo di LIME per spiegare le previsioni del modello

# Selezione di un'istanza di test casuale

# Spiegazione delle previsioni del modello per l'istanza selezionata

# Visualizzazione delle spiegazioni
